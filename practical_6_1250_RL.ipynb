# %% [markdown]
#  Building a Random Agent for Reinforcement Learning Environments

# %%
# !pip install -q gymnasium

# %% [markdown]
# Random Agent for CliffWalking and Taxi

# %%
import gymnasium as gym
import numpy as np


# ---------------------------------------------------------
# RANDOM AGENT FUNCTION
# ---------------------------------------------------------

def random_agent(environment_name, episodes=10):

    print("\n" + "=" * 60)
    print("Environment:", environment_name)
    print("=" * 60)

    # 1. Create the environment
    env = gym.make(environment_name)

    episode_rewards = []

    # Repeat for each episode
    for episode in range(1, episodes + 1):

        # 2 & 3. Reset environment and observe initial state
        state, info = env.reset()

        total_reward = 0
        done = False
        step = 0

        # Continue until episode terminates
        while not done:

            # 4 & 5. Identify action space and select random action
            action = env.action_space.sample()

            # 6 & 7. Execute action and observe next state and reward
            next_state, reward, terminated, truncated, info = env.step(action)

            # Add reward
            total_reward += reward
            step += 1

            # 8. Move to next state
            state = next_state

            # Check whether episode has terminated
            done = terminated or truncated

        # Store total reward of this episode
        episode_rewards.append(total_reward)

        # 10. Print total reward for each episode
        print(
            "Episode", episode,
            "| Steps:", step,
            "| Total Reward:", total_reward
        )

    # 9. Calculate average reward
    average_reward = np.mean(episode_rewards)

    print("-" * 60)
    print("Total Reward of all episodes:", sum(episode_rewards))
    print("Average Reward:", average_reward)
    print("-" * 60)

    env.close()

    return episode_rewards, average_reward


# ---------------------------------------------------------
# RUN RANDOM AGENT ON CLIFF WALKING
# ---------------------------------------------------------

cliff_rewards, cliff_average = random_agent(
    "CliffWalking-v1",
    episodes=10
)


# ---------------------------------------------------------
# RUN RANDOM AGENT ON TAXI
# ---------------------------------------------------------

taxi_rewards, taxi_average = random_agent(
    "Taxi-v4",
    episodes=10

)
# Out:
# ============================================================
# Environment: CliffWalking-v1
# ============================================================
# Episode 1 | Steps: 5203 | Total Reward: -56881
# Episode 2 | Steps: 4974 | Total Reward: -50514
# Episode 3 | Steps: 11671 | Total Reward: -112849
# Episode 4 | Steps: 20199 | Total Reward: -205329
# Episode 5 | Steps: 4425 | Total Reward: -47292
# Episode 6 | Steps: 2313 | Total Reward: -20529
# Episode 7 | Steps: 2961 | Total Reward: -28998
# Episode 8 | Steps: 1993 | Total Reward: -20110
# Episode 9 | Steps: 2227 | Total Reward: -21334
# Episode 10 | Steps: 1711 | Total Reward: -16561
# ------------------------------------------------------------
# Total Reward of all episodes: -580397
# Average Reward: -58039.7
# ------------------------------------------------------------
#
# ============================================================
# Environment: Taxi-v4
# ============================================================
# Episode 1 | Steps: 200 | Total Reward: -740
# Episode 2 | Steps: 200 | Total Reward: -812
# Episode 3 | Steps: 200 | Total Reward: -668
# Episode 4 | Steps: 200 | Total Reward: -866
# Episode 5 | Steps: 200 | Total Reward: -632
# Episode 6 | Steps: 200 | Total Reward: -812
# Episode 7 | Steps: 120 | Total Reward: -414
# Episode 8 | Steps: 200 | Total Reward: -650
# Episode 9 | Steps: 200 | Total Reward: -812
# Episode 10 | Steps: 200 | Total Reward: -821
# ------------------------------------------------------------
# Total Reward of all episodes: -7227
# Average Reward: -722.7
# ------------------------------------------------------------

# %% [markdown]
# Show the State → Action → Reward → Next State

# %%
import gymnasium as gym

env = gym.make("CliffWalking-v1")

state, info = env.reset()

print("Initial State:", state)
print("Action Space:", env.action_space)

for step in range(10):

    # Select random action
    action = env.action_space.sample()

    # Execute action
    next_state, reward, terminated, truncated, info = env.step(action)

    print("\nStep:", step + 1)
    print("State      :", state)
    print("Action     :", action)
    print("Reward     :", reward)
    print("Next State :", next_state)

    state = next_state

    if terminated or truncated:
        print("\nEpisode terminated.")
        break

env.close()
# Out:
# Initial State: 36
# Action Space: Discrete(4)
#
# Step: 1
# State      : 36
# Action     : 2
# Reward     : -1
# Next State : 36
#
# Step: 2
# State      : 36
# Action     : 2
# Reward     : -1
# Next State : 36
#
# Step: 3
# State      : 36
# Action     : 1
# Reward     : -100
# Next State : 36
#
# Step: 4
# State      : 36
# Action     : 3
# Reward     : -1
# Next State : 36
#
# Step: 5
# State      : 36
# Action     : 0
# Reward     : -1
# Next State : 24
#
# Step: 6
# State      : 24
# Action     : 3
# Reward     : -1
# Next State : 24
#
# Step: 7
# State      : 24
# Action     : 1
# Reward     : -1
# Next State : 25
#
# Step: 8
# State      : 25
# Action     : 0
# Reward     : -1
# Next State : 13
#
# Step: 9
# State      : 13
# Action     : 1
# Reward     : -1
# Next State : 14
#
# Step: 10
# State      : 14
# Action     : 0
# Reward     : -1
# Next State : 2
